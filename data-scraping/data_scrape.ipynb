# %% [markdown]
# # This Notebook collects the comments under the video of John Lewis 2025 Christmas Advertisment

# %%
# Step Logs 1
# Installing Important Packages
# %pip install python-dotenv
# !pip install google-api-python-client pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load data scraping API Key
import os
from dotenv import load_dotenv
load_dotenv("youtube_api.env")  # reads .env in current working directory
api_key = os.getenv("YOUTUBE_API_KEY")
# Sanity Check my API Key
# print(api_key)

# %%
# Scrape Preparation
import pandas as pd
import time
import re
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import data_scrape
import importlib
importlib.reload(data_scrape)
# Out:
# <module 'data_scrape' from 'd:\\Zhihuan Hao Important Documents\\NYU Grad Study Materials\\Spring 2026\\John-Lewis-2025-Christmas-Advertisment-Sentiment-Analysis\\data-scraping\\data_scrape.py'>

# %%
youtube = build('youtube', 'v3', developerKey=api_key)
video_list = ["dc5S4IV_NeA", "z1bRlnyQeDk"]
output_folder = os.path.join('..', 'data', 'scraped_raw')

# 遍历列表中的每一个视频 ID
for vid in video_list:
    print(f"------------\n🎬 Handling Video ID: {vid}")
    
    # 1. 获取 Channel Name (例如: "John Lewis & Partners")
    channel_name = data_scrape.get_channel_title(youtube, vid)
    
    # 2. 抓取评论数据
    df = data_scrape.scrape_all_comments_for_single_video(youtube, vid)
    
    if not df.empty:
        raw_filename = f"{vid}_{channel_name}_all_comments.csv"
        safe_filename = data_scrape.sanitize_filename(raw_filename)
        
        # 4. 【关键步骤】组合 文件夹路径 + 文件名
        # 结果类似于: data/scraped_raw/dc5S4IV_NeA_JohnLewis_all_comments.csv
        full_file_path = os.path.join(output_folder, safe_filename)
        df.to_csv(full_file_path, index=False, encoding='utf-8-sig')
        
print("\n🎉 All Job Done! Please check the csv files。")
# Out:
# ------------
# 🎬 Handling Video ID: dc5S4IV_NeA
# 🚀 Scrapping Video: dc5S4IV_NeA
#    ...Scrapped 580 Comments (Page 5)
#    ...Scrapped 1300 Comments (Page 10)
# ✅ Scraped 1297 Comments.
# ------------
# 🎬 Handling Video ID: z1bRlnyQeDk
# 🚀 Scrapping Video: z1bRlnyQeDk
#    ...Scrapped 668 Comments (Page 5)
#    ...Scrapped 1441 Comments (Page 10)
#    ...Scrapped 2360 Comments (Page 15)
# ✅ Scraped 2568 Comments.
#
# 🎉 All Job Done! Please check the csv files。
